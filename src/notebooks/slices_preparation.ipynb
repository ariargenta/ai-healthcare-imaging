# %% [markdown]
# # Create groups of slices

# %%
from glob import glob
import shutil
import os
import dicom2nifti

# %%
in_path = '../../datasets/DICOM/raw_files/slices'
out_path = '../../datasets/DICOM/dataset_groups/slices'

# %%
for patient in glob(in_path + '/*'):
    patient_name = os.path.basename(os.path.normpath(patient))
    number_folders = int(len(glob(patient + '/*')) / 64)

    for i in range(number_folders):
        output_path_name = os.path.join(out_path, patient_name + '_' + str(i))
        os.mkdir(output_path_name)
        
        for i, file in enumerate(glob(patient + '/*')):
            if i == 64 + 1:
                break
            shutil.move(file, output_path_name)

# %% [markdown]
# # Convert DICOM files into NIfTI

# %%
in_slices_path = '../../datasets/DICOM/dataset_groups/slices/*'
in_labels_path = '../../datasets/DICOM/dataset_groups/labels/*'
out_slices_path  ='../../datasets/NIfTI/slices'
out_labels_path = '../../datasets/NIfTI/labels'

list_images = glob(in_slices_path)
list_labels = glob(in_labels_path)

# %%
for patient in list_images:
    patient_name = os.path.basename(os.path.normpath(patient))
    dicom2nifti.dicom_series_to_nifti(patient, os.path.join(out_slices_path, patient_name + '.nii.gz'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 for patient in list_images:
#       2     patient_name = os.path.basename(os.path.normpath(patient))
# ----> 3     dicom2nifti.dicom_series_to_nifti(patient, os.path.join(out_slices_path, patient_name + '.nii.gz'))
#
# File c:\Users\arias\source\repos\ariargenta\ai-healthcare-imaging\env\Lib\site-packages\dicom2nifti\convert_dicom.py:81, in dicom_series_to_nifti(original_dicom_directory, output_file, reorient_nifti)
#      78     return dicom_array_to_nifti(dicom_input, output_file, reorient_nifti)
#      80 except AttributeError as exception:
# ---> 81     raise exception
#      83 finally:
#      84     # remove the copied data
#      85     shutil.rmtree(temp_directory)
#
# ...
